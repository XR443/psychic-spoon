# %% [markdown]
# #### Дано:
# $ 3 * \begin{pmatrix} x & 2 & 3 \\ -1 & y & 4 \end{pmatrix} + 2 * \begin{pmatrix} 1 & 2 & -5 \\ 2 & -6 & z \end{pmatrix}
# = \begin{pmatrix} 8 & v & -1 \\ 1 & 6 & 4 \end{pmatrix}$

# %% [markdown]
# #### Найти:
# $x, y, z, v$

# %% [markdown]
# #### Решение

# %% [markdown]
# $ 3 * \begin{pmatrix} x & 2 & 3 \\ -1 & y & 4 \end{pmatrix}
# = \begin{pmatrix} 3x & 6 & 9 \\ -3 & 3y & 12 \end{pmatrix}$

# %% [markdown]
# $ 2 * \begin{pmatrix} 1 & 2 & -5 \\ 2 & -6 & z \end{pmatrix}
# = \begin{pmatrix} 2 & 4 & -10 \\ 4 & -12 & 2z \end{pmatrix}$

# %% [markdown]
# $\begin{pmatrix} 3x & 6 & 9 \\ -3 & 3y & 12 \end{pmatrix} + \begin{pmatrix} 2 & 4 & -10 \\ 4 & -12 & 2z \end{pmatrix}
# = \begin{pmatrix} 8 & v & -1 \\ 1 & 6 & 4 \end{pmatrix}$

# %% [markdown]
# $
# \begin{cases}
# 3x + 2 = 8 \\
# 6 + 4 = v \\
# 3y - 12 = 6 \\
# 12 + 2z = 4 \\
# \end{cases}
# \implies
# \begin{cases}
# 3x = 6 \\
# v = 10 \\
# 3y = 18 \\
# 2z = -8 \\
# \end{cases}
# \implies
# \begin{cases}
# x = 2 \\
# v = 10 \\
# y = 6 \\
# z = -4 \\
# \end{cases}
# $

# %% [markdown]
# #### Ответ:
# $
# \begin{cases}
# x = 2 \\
# v = 10 \\
# y = 6 \\
# z = -4 \\
# \end{cases}
# $

# %% [markdown]
# #### NumPy проверка:

# %%
import numpy as np

x = 2
y = 6
z = -4
v = 10

A = np.matrix([[x,  2, 3], [-1, y, 4]])
B = np.matrix([[1, 2, -5], [2, -6, z]])
C = np.matrix([[8, v, -1], [1, 6, 4]])

R = 3 * A + 2 * B

assert (R & C).all()
