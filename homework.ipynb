# %% [markdown]
# # Домашняя работа № 3

# %% [markdown]
# ## Задание № 1

# %% [markdown]
# ### Конвертация из snake_case в camelCase и обратно.
#
# Функция самостоятельно распознает целевой формат и возбуждает исключение ValueError в случае смешения изначальных типов формата.

# %%
import change_string_format as chf

assert "reversedFormat" == chf.reformat("reversed_format")
assert "reversed_format" == chf.reformat("reversedFormat")
try:
    chf.reformat("invalid_reversedFormat")
    assert False
except ValueError:
    print("Возникла ошибка при конвертации строки, проверьте ввод функции")
# Out:
# reversedFormat
# reversed_format
# Возникла ошибка при конвертации строки, проверьте ввод функции

# %% [markdown]
# ### Конвертация в заданный формат
#
# Функция конвертирует в заданный формат (snake_case, camelCase) из snake_case или camelCase, игнорируя смешения типов форматирования исходной строки.

# %%
import change_string_format as chf

assert "camelCase" == chf.reformat("camel_case", "camelCase")
assert "snake_case" == chf.reformat("snakeCase", "snake_case")
assert "invalid_reversed_format" == chf.reformat("invalid_reversedFormat", "snake_case")
assert "invalidReversedFormat" == chf.reformat("invalid_reversedFormat", "camelCase")

# %% [markdown]
# ## Задание № 2

# %% [markdown]
# Функция, проверяющая корректность введенной даты. Ввод даты осуществляется в формате dd.mm.yyyy

# %%
import date_check as dc

assert dc.validate_date("29.02.2000")
assert not dc.validate_date("29.02.2001")
assert not dc.validate_date("31.04.1962")

# %% [markdown]
# ## Задание № 3

# %% [markdown]
# Функция, проверяющая введенное число на простоту

# %%
import is_simple as simple

assert simple.is_simple(17)
assert not simple.is_simple(20)
assert simple.is_simple(23)

# %% [markdown]
# ## Задание № 4

# %% [markdown]
# Пользователь вводит данные пользователей: имя, фамилию, возраст и ID. При вводе пустого поля цикл ввода заканчивается.
# Пользователи заносятся в словарь, где ключ это ID пользователя, а остальные данные записываются в виде кортежа.
# Имя и фамилия состоят только из символов и начинаются с большой буквы, возраст должен быть числом от 18 до 60, ID - целое число, дополненное до 8 знаков незначащими нулями, ID должен быть уникальным

# %%
import table

table_data: dict = table.get_table_data()
table.print_db(table_data)
# Out:
# Ввод пользователя
# Ввод пользователя
# Person with 00000034 already in db
# Ввод пользователя
# Ввод пользователя
# Ид             |Фамилия        |Имя            |Возраст
# 00000034       |Hrenpopadesh   |Boris          |45
# 00000065       |Turetstiy      |R              |34
